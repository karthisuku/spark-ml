# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('boston-home').getOrCreate()

# %%
data=spark.read.csv("./boston_housing.csv",header=True,inferSchema=True)

# %%
data.printSchema()
# Out:
# root
#  |-- crim: double (nullable = true)
#  |-- zn: double (nullable = true)
#  |-- indus: double (nullable = true)
#  |-- chas: integer (nullable = true)
#  |-- nox: double (nullable = true)
#  |-- rm: double (nullable = true)
#  |-- age: double (nullable = true)
#  |-- dis: double (nullable = true)
#  |-- rad: integer (nullable = true)
#  |-- tax: integer (nullable = true)
#  |-- ptratio: double (nullable = true)
#  |-- b: double (nullable = true)
#  |-- lstat: double (nullable = true)
#  |-- medv: double (nullable = true)

# %%
data.describe(data.columns).toPandas().transpose()
# Out:
#              0                   1                    2        3        4
# summary  count                mean               stddev      min      max
# crim       506  3.6135235573122535    8.601545105332491  0.00632  88.9762
# zn         506  11.363636363636363    23.32245299451514      0.0    100.0
# indus      506  11.136778656126504    6.860352940897589     0.46    27.74
# chas       506  0.0691699604743083   0.2539940413404101        0        1
# nox        506  0.5546950592885372  0.11587767566755584    0.385    0.871
# rm         506   6.284634387351787   0.7026171434153232    3.561     8.78
# age        506   68.57490118577078   28.148861406903595      2.9    100.0
# dis        506   3.795042687747034     2.10571012662761   1.1296  12.1265
# rad        506   9.549407114624506    8.707259384239366        1       24
# tax        506   408.2371541501976   168.53711605495903      187      711
# ptratio    506  18.455533596837967   2.1649455237144455     12.6     22.0
# b          506  356.67403162055257    91.29486438415782     0.32    396.9
# lstat      506  12.653063241106723    7.141061511348571     1.73    37.97
# medv       506  22.532806324110698    9.197104087379815      5.0     50.0

# %% [markdown]
# # Getting the feature columns

# %%
features_columns=data.columns[:-1] # except the last column

# %%
print(features_columns)
# Out:
# ['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'b', 'lstat']

# %% [markdown]
# # Getting the vector assembler

# %%
from pyspark.ml.feature import VectorAssembler

# %%
assembler=VectorAssembler(inputCols=features_columns,outputCol="features")

# %%
transformed_data_with_feature_and_label=assembler.transform(data)

# %% [markdown]
# # Train test split data

# %%
train, test = transformed_data_with_feature_and_label.randomSplit([0.7,0.3])

# %%
train.toPandas().transpose()
# Out:
#                                                         0    \
# crim                                                0.00906
# zn                                                       90
# indus                                                  2.97
# chas                                                      0
# nox                                                     0.4
# rm                                                    7.088
# age                                                    20.8
# dis                                                  7.3073
# rad                                                       1
# tax                                                     285
# ptratio                                                15.3
# b                                                    394.72
# lstat                                                  7.85
# medv                                                   32.2
# features  [0.00906, 90.0, 2.97, 0.0, 0.4, 7.088, 20.8, 7...
#
#                                                         1    \
# crim                                                0.01301
# zn                                                       35
# indus                                                  1.52
# chas                                                      0
# nox                                                   0.442
# rm                                                    7.241
# age                                                    49.3
# dis                                                  7.0379
# rad                                                       1
# tax                                                     284
# ptratio                                                15.5
# b                                                    394.74
# lstat                                                  5.49
# medv                                                   32.7
# features  [0.01301, 35.0, 1.52, 0.0, 0.442, 7.241, 49.3,...
#
#                                                         2    \
# crim                                                 0.0136
# zn                                                       75
# indus                                                     4
# chas                                                      0
# nox                                                    0.41
# rm                                                    5.888
# age                                                    47.6
# dis                                                  7.3197
# rad                                                       3
# tax                                                     469
# ptratio                                                21.1
# b                                                     396.9
# lstat                                                  14.8
# medv                                                   18.9
# features  [0.0136, 75.0, 4.0, 0.0, 0.41, 5.888, 47.6, 7....
#
#                                                         3    \
# crim                                                0.01381
# zn                                                       80
# indus                                                  0.46
# chas                                                      0
# nox                                                   0.422
# rm                                                    7.875
# age                                                      32
# dis                                                  5.6484
# rad                                                       4
# tax                                                     255
# ptratio                                                14.4
# b                                                    394.23
# lstat                                                  2.97
# medv                                                     50
# features  [0.01381, 80.0, 0.46, 0.0, 0.422, 7.875, 32.0,...
#
#                                                         4    \
# crim                                                0.01432
# zn                                                      100
# indus                                                  1.32
# chas                                                      0
# nox                                                   0.411
# rm                                                    6.816
# age                                                    40.5
# dis                                                  8.3248
# rad                                                       5
# tax                                                     256
# ptratio                                                15.1
# b                                                     392.9
# lstat                                                  3.95
# medv                                                   31.6
# features  [0.01432, 100.0, 1.32, 0.0, 0.411, 6.816, 40.5...
#
#                                                         5    \
# crim                                                0.01439
# zn                                                       60
# indus                                                  2.93
# chas                                                      0
# nox                                                   0.401
# rm                                                    6.604
# age                                                    18.8
# dis                                                  6.2196
# rad                                                       1
# tax                                                     265
# ptratio                                                15.6
# b                                                     376.7
# lstat                                                  4.38
# medv                                                   29.1
# features  [0.01439, 60.0, 2.93, 0.0, 0.401, 6.604, 18.8,...
#
#                                                         6    \
# crim                                                0.01501
# zn                                                       80
# indus                                                  2.01
# chas                                                      0
# nox                                                   0.435
# rm                                                    6.635
# age                                                    29.7
# dis                                                   8.344
# rad                                                       4
# tax                                                     280
# ptratio                                                  17
# b                                                    390.94
# lstat                                                  5.99
# medv                                                   24.5
# features  [0.01501, 80.0, 2.01, 0.0, 0.435, 6.635, 29.7,...
#
#                                                         7    \
# crim                                                0.01501
# zn                                                       90
# indus                                                  1.21
# chas                                                      1
# nox                                                   0.401
# rm                                                    7.923
# age                                                    24.8
# dis                                                   5.885
# rad                                                       1
# tax                                                     198
# ptratio                                                13.6
# b                                                    395.52
# lstat                                                  3.16
# medv                                                     50
# features  [0.01501, 90.0, 1.21, 1.0, 0.401, 7.923, 24.8,...
#
#                                                         8    \
# crim                                                0.01538
# zn                                                       90
# indus                                                  3.75
# chas                                                      0
# nox                                                   0.394
# rm                                                    7.454
# age                                                    34.2
# dis                                                  6.3361
# rad                                                       3
# tax                                                     244
# ptratio                                                15.9
# b                                                    386.34
# lstat                                                  3.11
# medv                                                     44
# features  [0.01538, 90.0, 3.75, 0.0, 0.394, 7.454, 34.2,...
#
#                                                         9    \
# crim                                                0.01709
# zn                                                       90
# indus                                                  2.02
# chas                                                      0
# nox                                                    0.41
# rm                                                    6.728
# age                                                    36.1
# dis                                                 12.1265
# rad                                                       5
# tax                                                     187
# ptratio                                                  17
# b                                                    384.46
# lstat                                                   4.5
# medv                                                   30.1
# features  [0.01709, 90.0, 2.02, 0.0, 0.41, 6.728, 36.1, ...
#
#                                 ...                          \
# crim                            ...
# zn                              ...
# indus                           ...
# chas                            ...
# nox                             ...
# rm                              ...
# age                             ...
# dis                             ...
# rad                             ...
# tax                             ...
# ptratio                         ...
# b                               ...
# lstat                           ...
# medv                            ...
# features                        ...
#
#                                                         338  \
# crim                                                22.5971
# zn                                                        0
# indus                                                  18.1
# chas                                                      0
# nox                                                     0.7
# rm                                                        5
# age                                                    89.5
# dis                                                  1.5184
# rad                                                      24
# tax                                                     666
# ptratio                                                20.2
# b                                                     396.9
# lstat                                                 31.99
# medv                                                    7.4
# features  [22.5971, 0.0, 18.1, 0.0, 0.7, 5.0, 89.5, 1.51...
#
#                                                         339  \
# crim                                                23.6482
# zn                                                        0
# indus                                                  18.1
# chas                                                      0
# nox                                                   0.671
# rm                                                     6.38
# age                                                    96.2
# dis                                                  1.3861
# rad                                                      24
# tax                                                     666
# ptratio                                                20.2
# b                                                     396.9
# lstat                                                 23.69
# medv                                                   13.1
# features  [23.6482, 0.0, 18.1, 0.0, 0.671, 6.38, 96.2, 1...
#
#                                                         340  \
# crim                                                24.3938
# zn                                                        0
# indus                                                  18.1
# chas                                                      0
# nox                                                     0.7
# rm                                                    4.652
# age                                                     100
# dis                                                  1.4672
# rad                                                      24
# tax                                                     666
# ptratio                                                20.2
# b                                                     396.9
# lstat                                                 28.28
# medv                                                   10.5
# features  [24.3938, 0.0, 18.1, 0.0, 0.7, 4.652, 100.0, 1...
#
#                                                         341  \
# crim                                                25.0461
# zn                                                        0
# indus                                                  18.1
# chas                                                      0
# nox                                                   0.693
# rm                                                    5.987
# age                                                     100
# dis                                                  1.5888
# rad                                                      24
# tax                                                     666
# ptratio                                                20.2
# b                                                     396.9
# lstat                                                 26.77
# medv                                                    5.6
# features  [25.0461, 0.0, 18.1, 0.0, 0.693, 5.987, 100.0,...
#
#                                                         342  \
# crim                                                25.9406
# zn                                                        0
# indus                                                  18.1
# chas                                                      0
# nox                                                   0.679
# rm                                                    5.304
# age                                                    89.1
# dis                                                  1.6475
# rad                                                      24
# tax                                                     666
# ptratio                                                20.2
# b                                                    127.36
# lstat                                                 26.64
# medv                                                   10.4
# features  [25.9406, 0.0, 18.1, 0.0, 0.679, 5.304, 89.1, ...
#
#                                                         343  \
# crim                                                28.6558
# zn                                                        0
# indus                                                  18.1
# chas                                                      0
# nox                                                   0.597
# rm                                                    5.155
# age                                                     100
# dis                                                  1.5894
# rad                                                      24
# tax                                                     666
# ptratio                                                20.2
# b                                                    210.97
# lstat                                                 20.08
# medv                                                   16.3
# features  [28.6558, 0.0, 18.1, 0.0, 0.597, 5.155, 100.0,...
#
#                                                         344  \
# crim                                                37.6619
# zn                                                        0
# indus                                                  18.1
# chas                                                      0
# nox                                                   0.679
# rm                                                    6.202
# age                                                    78.7
# dis                                                  1.8629
# rad                                                      24
# tax                                                     666
# ptratio                                                20.2
# b                                                     18.82
# lstat                                                 14.52
# medv                                                   10.9
# features  [37.6619, 0.0, 18.1, 0.0, 0.679, 6.202, 78.7, ...
#
#                                                         345  \
# crim                                                38.3518
# zn                                                        0
# indus                                                  18.1
# chas                                                      0
# nox                                                   0.693
# rm                                                    5.453
# age                                                     100
# dis                                                  1.4896
# rad                                                      24
# tax                                                     666
# ptratio                                                20.2
# b                                                     396.9
# lstat                                                 30.59
# medv                                                      5
# features  [38.3518, 0.0, 18.1, 0.0, 0.693, 5.453, 100.0,...
#
#                                                         346  \
# crim                                                41.5292
# zn                                                        0
# indus                                                  18.1
# chas                                                      0
# nox                                                   0.693
# rm                                                    5.531
# age                                                    85.4
# dis                                                  1.6074
# rad                                                      24
# tax                                                     666
# ptratio                                                20.2
# b                                                    329.46
# lstat                                                 27.38
# medv                                                    8.5
# features  [41.5292, 0.0, 18.1, 0.0, 0.693, 5.531, 85.4, ...
#
#                                                         347
# crim                                                88.9762
# zn                                                        0
# indus                                                  18.1
# chas                                                      0
# nox                                                   0.671
# rm                                                    6.968
# age                                                    91.9
# dis                                                  1.4165
# rad                                                      24
# tax                                                     666
# ptratio                                                20.2
# b                                                     396.9
# lstat                                                 17.21
# medv                                                   10.4
# features  [88.9762, 0.0, 18.1, 0.0, 0.671, 6.968, 91.9, ...
#
# [15 rows x 348 columns]

# %%
train.count()
# Out:
# 348

# %%
test.count()
# Out:
# 158

# %% [markdown]
# # Using Spark ML Regression Model

# %%
from pyspark.ml.regression import LinearRegression

# %%
linearRegressionAlgorithm=LinearRegression(featuresCol="features",labelCol="medv")

# %%
model=linearRegressionAlgorithm.fit(train)

# %%
evaluvation_summary=model.evaluate(test)

# %%
predictions=model.transform(test)

# %%
predictions.select(predictions.columns[13:]).show() # here I am filtering out some columns just for the figure to fit
# Out:
# +----+--------------------+------------------+
# |medv|            features|        prediction|
# +----+--------------------+------------------+
# |24.0|[0.00632,18.0,2.3...| 30.90720546820699|
# |22.0|[0.01096,55.0,2.2...| 27.79739337041719|
# |35.4|[0.01311,90.0,1.2...|    31.47279484776|
# |32.9|[0.01778,95.0,1.4...|31.281917417484838|
# |31.1|[0.02187,60.0,2.9...| 32.41260619141315|
# |23.9|[0.02543,55.0,3.7...| 28.48769142522596|
# |21.6|[0.02731,0.0,7.07...| 25.36311123638822|
# |25.0|[0.02875,28.0,15....|29.135875961325876|
# |26.6|[0.02899,40.0,1.2...|22.191871399937757|
# |28.7|[0.02985,0.0,2.18...|25.624454163395058|
# |20.6|[0.03306,0.0,5.19...|21.964725603318588|
# |19.5|[0.03427,0.0,5.19...|20.003836958310696|
# |28.5|[0.03502,80.0,4.9...| 34.03326970904453|
# |22.0|[0.03537,34.0,6.0...|29.308107041274084|
# |20.9|[0.03548,80.0,3.6...| 21.97570413334767|
# |45.4|[0.03578,20.0,3.3...| 39.51064839497955|
# |27.9|[0.03615,80.0,4.9...|32.324875191506095|
# |34.6|[0.03768,80.0,1.5...|35.569763867356244|
# |23.2|[0.03871,52.5,5.3...|27.511061674389325|
# |22.0|[0.03932,0.0,3.41...|28.011620780900888|
# +----+--------------------+------------------+
# only showing top 20 rows
